# %% [markdown]
# # Training Convergence Plots for Learning Punctuation

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Serif'
plt.rcParams['font.serif'] = 'Liberation Serif'
import pickle
import os
print(os.getcwd())
import time
import gc
import torch
import bisect

from conv_plots_funcs import train_conv_plots

#import empirical cdf
# import sys
# sys.path.append(os.path.abspath('../../src'))

from data_processing import gen_ckpt_steps, move_dict_to_device, get_other_err, get_mop_ratios_ckpt, compute_ratio
# sys.path.append(os.path.abspath('..'))

from check_ecdf import get_empirical_cdf
# Out:
# /home/sultand/TFs_do_KF_ICL/src
# /home/sultand/TFs_do_KF_ICL/src
# /home/sultand/TFs_do_KF_ICL/src
# Using device: cuda
# Using device: cuda

# %%
valA = "ortho"
valC = "_ident_C"
state_dim = 5
ckpt_step = 8
batch_size = 512 #512 #4096
gpus=2
num_val_sys = 25
experiment = "250112_043028.07172b_multi_sys_trace_ortho_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000" # experiment to load
datasource = "val"
nope = False
single_system = True
zero_cut = False


compute_more_ckpts = False

# %%
kal_ckpt = 141000 #60000 #81000 #28500
train_conv_plots([experiment], ["Identity"], [kal_ckpt], valA, valC, num_val_sys, compute_more_ckpts, None, 3000, 180000, 3000, state_dim, single_system=single_system, nope=nope, batch_size=batch_size, gpus=gpus, zero_cut=zero_cut)
# Out:
# /home/sultand/TFs_do_KF_ICL/outputs/train_conv/training_dist_comparison_val_ortho_state_dim_5_val_sys_25_1738319448.3781545.pdf
# quantiles 5 path exists?: True
# ckpt_steps: [3000, 6000, 9000, 12000, 15000, 18000, 21000, 24000, 27000, 30000, 33000, 36000, 39000, 42000, 45000, 48000, 51000, 54000, 57000, 60000, 63000, 66000, 69000, 72000, 75000, 78000, 81000, 84000, 87000, 90000, 93000, 96000, 99000, 102000, 105000, 108000, 111000, 114000, 117000, 120000, 123000, 126000, 129000, 132000, 135000, 138000, 141000, 144000, 147000, 150000, 153000, 156000, 159000, 162000, 165000, 168000, 171000, 174000, 177000, 180000]
# quantiles already exist for 250112_043028.07172b_multi_sys_trace_ortho_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000, and single_system=True
# keys in the file: ['pred_ckpts', 'quantiles']
# quantiles shape after load: (0,)
# loading quantiles_5 and quantiles_20
# quantiles shape (0,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 kal_ckpt = 141000 #60000 #81000 #28500
# ----> 2 train_conv_plots([experiment], ["Identity"], [kal_ckpt], valA, valC, num_val_sys, compute_more_ckpts, None, 3000, 180000, 3000, state_dim, single_system=single_system, nope=nope, batch_size=batch_size, gpus=gpus, zero_cut=zero_cut)
#
# File ~/TFs_do_KF_ICL/src/conv_plots_funcs.py:234, in train_conv_plots(experiments, trainAs, kal_ckpt, valA, C_dist, num_val_systems, compute_more_ckpts, ind, min_ckpt, max_ckpt, interval, nx, needle_in_haystack, single_system, max_ir_len, nope, batch_size, gpus, zero_cut)
#     232 print("quantiles shape", quantiles.shape)
#     233 ##plotting stuff
# --> 234 ax.plot(pred_ckpts, quantiles[:,1], marker=".", linewidth=3, color= colors[0], label=(trainAs[i] if not single_system else "") + " TF" + (" 1 after" if single_system else ""), markersize=5 if valA == "gaussA" else 10)
#     236 if not valA == "gaussA":
#     237     plt.fill_between(pred_ckpts, quantiles[:,0], quantiles[:,2], color=colors[0], alpha=0.2) #, label='25th-75th Percentile Range')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# # Zero Cut Plot

# %%
valA = "gaussA"
valC = "_gauss_C"
batch_size = 512 #512 #4096
gpus=2
num_val_sys = 25
experiment_zero_train = "250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000" # experiment to load
experiment_multi_train = "250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000"
kal_ckpt_zero_train = 90000 
# kal_ckpt_multi_train = 30000 #180000
datasource = "val"
state_dim = 10

# %%
kal_err_zero_train = get_other_err(valA, valC, kal_ckpt_zero_train, experiment_zero_train, "Kalman_rem", state_dim, zero_cut=True)

tf_err_zero_train, pred_ckpt = get_mop_ratios_ckpt(valA, valC, kal_ckpt_zero_train, experiment_zero_train, state_dim, zero_cut=True)

ols_irs = []
for ir in range(1, 4):
    ols_ir = get_other_err(valA, valC, kal_ckpt_zero_train, experiment_zero_train, f"OLS_ir_{ir}", state_dim, zero_cut=True)
    ols_irs.append(compute_ratio(None, ols_ir, kal_err_zero_train).cpu().numpy())

tf_err_rat_zero_train = compute_ratio(None, tf_err_zero_train, kal_err_zero_train)
tf_err_rat_zero_train = tf_err_rat_zero_train.cpu().numpy()
print("shape of tf_err_rat_zero_train: ", tf_err_rat_zero_train.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 kal_err_zero_train = get_other_err(valA, valC, kal_ckpt_zero_train, experiment_zero_train, "Kalman_rem", state_dim, zero_cut=True)
#       3 tf_err_zero_train, pred_ckpt = get_mop_ratios_ckpt(valA, valC, kal_ckpt_zero_train, experiment_zero_train, state_dim, zero_cut=True)
#       5 ols_irs = []
#
# File ~/TFs_do_KF_ICL/src/data_processing.py:65, in get_other_err(valA, C_dist, ckpt_step, exper, curve, nx, single_system, nope, zero_cut, train_conv)
#      63     gc.collect()
#      64 else:
# ---> 65     raise ValueError(f"Preds do not exist for this checkpoint at:\n{path}")
#      66 return curve_err
#
# ValueError: Preds do not exist for this checkpoint at:
# ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=90000.ckpt/zero_cut_gaussA_state_dim_10_err_lss.pkl

# %%
#save zero train data
os.makedirs("../outputs/GPT2/" + experiment_zero_train + "/context", exist_ok=True)
np.save("../outputs/GPT2/" + experiment_zero_train + f"/context/tf_err_rat_zero_train_step_{kal_ckpt_zero_train}.npy", tf_err_rat_zero_train)
np.save("../outputs/GPT2/" + experiment_zero_train + "/context/ols_irs_zero_train.npy", ols_irs)

# %%
experiment_multi_train = "250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000"
valA = "ortho_haar"
valC = "_ident_C"
state_dim = 5
batch_size = 512
gpus=1

max_ckpt = 183000

# %%
for kal_ckpt_multi_train in np.arange(1000, max_ckpt, 1000):
    if kal_ckpt_multi_train < max_ckpt:
        train_conv = True
    else:
        train_conv = False

    tf_err_multi_train, pred_ckpt = get_mop_ratios_ckpt(valA, valC, kal_ckpt_multi_train, experiment_multi_train, state_dim, zero_cut=True, train_conv=train_conv)

    if tf_err_multi_train is None:
        print("No data for step: ", kal_ckpt_multi_train)
        continue
    # an_sim_err_multi_train = get_other_err(valA, valC, kal_ckpt_multi_train, experiment_multi_train, "Analytical_Simulation", state_dim, zero_cut=True, train_conv=train_conv)
    # an_sim_err_multi_train = compute_ratio(None, an_sim_err_multi_train, kal_err_zero_train).cpu().numpy()

    # ols_irs = []
    # for ir in range(1, 4):
    #     ols_ir = get_other_err(valA, valC, kal_ckpt_multi_train, experiment_zero_train, f"OLS_ir_{ir}", state_dim, zero_cut=True)
    #     ols_irs.append(compute_ratio(None, ols_ir, kal_err_zero_train).cpu().numpy())

    tf_err_rat_multi_train = compute_ratio(None, tf_err_multi_train, kalman_err=None)
    tf_err_rat_multi_train = tf_err_rat_multi_train.cpu().numpy()
    print("shape of tf_err_rat_multi_train: ", tf_err_rat_multi_train.shape)

    #save the data
    os.makedirs("../outputs/GPT2/" + experiment_multi_train + "/context", exist_ok=True)
    np.save("../outputs/GPT2/" + experiment_multi_train + f"/context/tf_err_rat_multi_train_step_{kal_ckpt_multi_train}.npy", tf_err_rat_multi_train)
# Out:
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=1000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=2000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=3000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=4000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=5000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=6000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=7000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=8000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=9000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  9000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=10000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  10000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=11000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=12000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  12000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=13000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  13000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=14000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=15000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  15000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=16000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  16000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=17000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=18000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  18000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=19000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  19000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=20000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=21000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  21000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=22000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  22000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=23000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=24000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  24000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=25000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  25000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=26000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=27000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  27000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=28000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  28000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=29000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=30000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  30000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=31000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  31000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=32000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=33000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  33000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=34000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  34000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=35000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  35000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=36000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  36000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=37000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=38000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  38000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=39000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  39000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=40000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  40000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=41000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  41000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=42000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=43000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  43000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=44000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  44000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=45000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  45000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=46000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  46000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=47000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=48000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  48000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=49000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  49000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=50000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  50000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=51000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  51000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=52000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=53000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  53000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=54000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  54000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=55000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  55000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=56000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  56000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=57000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=58000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  58000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=59000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  59000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=60000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  60000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=61000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  61000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=62000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=63000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  63000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=64000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  64000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=65000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  65000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=66000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  66000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=67000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=68000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  68000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=69000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  69000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=70000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  70000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=71000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  71000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=72000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=73000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  73000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=74000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  74000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=75000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  75000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=76000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  76000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=77000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=78000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  78000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=79000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  79000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=80000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  80000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=81000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  81000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=82000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=83000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  83000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=84000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  84000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=85000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  85000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=86000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  86000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=87000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  87000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=88000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  88000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=89000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  89000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=90000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  90000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=91000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  91000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=92000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=93000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  93000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=94000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  94000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=95000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  95000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=96000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  96000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=97000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  97000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=98000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  98000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=99000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  99000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=100000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  100000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=101000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  101000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=102000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=103000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  103000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=104000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  104000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=105000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  105000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=106000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  106000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=107000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  107000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=108000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  108000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=109000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  109000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=110000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  110000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=111000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  111000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=112000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=113000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  113000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=114000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  114000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=115000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  115000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=116000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  116000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=117000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  117000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=118000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  118000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=119000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  119000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=120000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  120000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=121000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  121000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=122000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=123000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  123000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=124000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  124000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=125000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  125000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=126000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  126000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=127000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  127000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=128000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  128000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=129000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  129000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=130000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  130000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=131000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  131000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=132000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=133000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  133000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=134000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  134000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=135000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  135000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=136000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  136000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=137000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  137000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=138000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  138000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=139000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  139000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=140000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  140000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=141000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  141000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=142000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=143000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  143000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=144000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  144000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=145000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  145000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=146000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  146000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=147000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  147000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=148000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  148000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=149000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  149000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=150000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  150000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=151000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  151000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=152000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=153000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  153000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=154000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  154000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=155000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  155000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=156000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  156000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=157000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  157000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=158000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  158000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=159000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  159000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=160000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  160000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=161000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  161000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=162000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=163000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  163000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=164000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  164000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=165000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  165000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=166000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  166000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=167000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  167000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=168000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  168000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=169000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  169000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=170000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  170000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=171000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  171000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=172000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=173000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  173000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=174000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  174000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=175000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  175000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=176000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  176000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=177000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  177000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=178000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  178000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=179000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  179000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=180000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  180000
# path does not exist: ../outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=181000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# No data for step:  181000
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250418_125901.8d6b22_multi_sys_trace_ortho_haar_state_dim_5_ident_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_ident_C_step=182000.ckpt/train_conv_zero_cut_ortho_haar_state_dim_5_err_lss.pkl
# Loaded Transformer Errors
# err shape: torch.Size([100, 1000, 251])
# ratios shape: torch.Size([100, 1000, 251])
# ratios shape after median: torch.Size([100, 251])
# shape of tf_err_rat_multi_train:  (3, 251)

# %%
# #load the data
# tf_err_rat_zero_train = np.load("../outputs/GPT2/" + experiment_zero_train + "/context/tf_err_rat_zero_train.npy")
# ols_irs = np.load("../outputs/GPT2/" + experiment_zero_train + "/context/ols_irs_zero_train.npy")

# print("tf_err_rat_zero_train: ", tf_err_rat_zero_train)

ckpt_steps = []
tf_err_multi_trains = []
for kal_ckpt_multi_train in np.arange(1000, max_ckpt, 1000):

    try:
        tf_err_multi_train = np.load("../outputs/GPT2/" + experiment_multi_train + f"/context/tf_err_rat_multi_train_step_{kal_ckpt_multi_train}.npy")
        print(f"kal_ckpt_multi_train: {kal_ckpt_multi_train}")
        # print(f"kal_ckpt_multi_train: {kal_ckpt_multi_train}, tf_err_multi_train: {tf_err_multi_train}")
        tf_err_multi_trains.append(tf_err_multi_train)
    except FileNotFoundError:
        print(f"File not found for kal_ckpt_multi_train: {kal_ckpt_multi_train}")
        continue

    ckpt_steps.append(kal_ckpt_multi_train)

# tf_err_rat_multi_train_3k = np.load("../outputs/GPT2/" + experiment_multi_train + "/context/tf_err_rat_multi_train_step_3000.npy")
# tf_err_rat_multi_train_30k = np.load("../outputs/GPT2/" + experiment_multi_train + "/context/tf_err_rat_multi_train_step_30000.npy")
# tf_err_rat_multi_train_96k = np.load("../outputs/GPT2/" + experiment_multi_train + "/context/tf_err_rat_multi_train_step_96000.npy")
# tf_err_rat_multi_train_180k = np.load("../outputs/GPT2/" + experiment_multi_train + "/context/tf_err_rat_multi_train_step_180000.npy")
# Out:
# kal_ckpt_multi_train: 1000
# kal_ckpt_multi_train: 2000
# kal_ckpt_multi_train: 3000
# kal_ckpt_multi_train: 4000
# kal_ckpt_multi_train: 5000
# kal_ckpt_multi_train: 6000
# kal_ckpt_multi_train: 7000
# kal_ckpt_multi_train: 8000
# File not found for kal_ckpt_multi_train: 9000
# File not found for kal_ckpt_multi_train: 10000
# kal_ckpt_multi_train: 11000
# File not found for kal_ckpt_multi_train: 12000
# File not found for kal_ckpt_multi_train: 13000
# kal_ckpt_multi_train: 14000
# File not found for kal_ckpt_multi_train: 15000
# File not found for kal_ckpt_multi_train: 16000
# kal_ckpt_multi_train: 17000
# File not found for kal_ckpt_multi_train: 18000
# File not found for kal_ckpt_multi_train: 19000
# kal_ckpt_multi_train: 20000
# File not found for kal_ckpt_multi_train: 21000
# File not found for kal_ckpt_multi_train: 22000
# kal_ckpt_multi_train: 23000
# File not found for kal_ckpt_multi_train: 24000
# File not found for kal_ckpt_multi_train: 25000
# kal_ckpt_multi_train: 26000
# File not found for kal_ckpt_multi_train: 27000
# File not found for kal_ckpt_multi_train: 28000
# kal_ckpt_multi_train: 29000
# File not found for kal_ckpt_multi_train: 30000
# File not found for kal_ckpt_multi_train: 31000
# kal_ckpt_multi_train: 32000
# File not found for kal_ckpt_multi_train: 33000
# File not found for kal_ckpt_multi_train: 34000
# File not found for kal_ckpt_multi_train: 35000
# File not found for kal_ckpt_multi_train: 36000
# kal_ckpt_multi_train: 37000
# File not found for kal_ckpt_multi_train: 38000
# File not found for kal_ckpt_multi_train: 39000
# File not found for kal_ckpt_multi_train: 40000
# File not found for kal_ckpt_multi_train: 41000
# kal_ckpt_multi_train: 42000
# File not found for kal_ckpt_multi_train: 43000
# File not found for kal_ckpt_multi_train: 44000
# File not found for kal_ckpt_multi_train: 45000
# File not found for kal_ckpt_multi_train: 46000
# kal_ckpt_multi_train: 47000
# File not found for kal_ckpt_multi_train: 48000
# File not found for kal_ckpt_multi_train: 49000
# File not found for kal_ckpt_multi_train: 50000
# File not found for kal_ckpt_multi_train: 51000
# kal_ckpt_multi_train: 52000
# File not found for kal_ckpt_multi_train: 53000
# File not found for kal_ckpt_multi_train: 54000
# File not found for kal_ckpt_multi_train: 55000
# File not found for kal_ckpt_multi_train: 56000
# kal_ckpt_multi_train: 57000
# File not found for kal_ckpt_multi_train: 58000
# File not found for kal_ckpt_multi_train: 59000
# File not found for kal_ckpt_multi_train: 60000
# File not found for kal_ckpt_multi_train: 61000
# kal_ckpt_multi_train: 62000
# File not found for kal_ckpt_multi_train: 63000
# File not found for kal_ckpt_multi_train: 64000
# File not found for kal_ckpt_multi_train: 65000
# File not found for kal_ckpt_multi_train: 66000
# kal_ckpt_multi_train: 67000
# File not found for kal_ckpt_multi_train: 68000
# File not found for kal_ckpt_multi_train: 69000
# File not found for kal_ckpt_multi_train: 70000
# File not found for kal_ckpt_multi_train: 71000
# kal_ckpt_multi_train: 72000
# File not found for kal_ckpt_multi_train: 73000
# File not found for kal_ckpt_multi_train: 74000
# File not found for kal_ckpt_multi_train: 75000
# File not found for kal_ckpt_multi_train: 76000
# kal_ckpt_multi_train: 77000
# File not found for kal_ckpt_multi_train: 78000
# File not found for kal_ckpt_multi_train: 79000
# File not found for kal_ckpt_multi_train: 80000
# File not found for kal_ckpt_multi_train: 81000
# kal_ckpt_multi_train: 82000
# File not found for kal_ckpt_multi_train: 83000
# File not found for kal_ckpt_multi_train: 84000
# File not found for kal_ckpt_multi_train: 85000
# File not found for kal_ckpt_multi_train: 86000
# File not found for kal_ckpt_multi_train: 87000
# File not found for kal_ckpt_multi_train: 88000
# File not found for kal_ckpt_multi_train: 89000
# File not found for kal_ckpt_multi_train: 90000
# File not found for kal_ckpt_multi_train: 91000
# kal_ckpt_multi_train: 92000
# File not found for kal_ckpt_multi_train: 93000
# File not found for kal_ckpt_multi_train: 94000
# File not found for kal_ckpt_multi_train: 95000
# File not found for kal_ckpt_multi_train: 96000
# File not found for kal_ckpt_multi_train: 97000
# File not found for kal_ckpt_multi_train: 98000
# File not found for kal_ckpt_multi_train: 99000
# File not found for kal_ckpt_multi_train: 100000
# File not found for kal_ckpt_multi_train: 101000
# kal_ckpt_multi_train: 102000
# File not found for kal_ckpt_multi_train: 103000
# File not found for kal_ckpt_multi_train: 104000
# File not found for kal_ckpt_multi_train: 105000
# File not found for kal_ckpt_multi_train: 106000
# File not found for kal_ckpt_multi_train: 107000
# File not found for kal_ckpt_multi_train: 108000
# File not found for kal_ckpt_multi_train: 109000
# File not found for kal_ckpt_multi_train: 110000
# File not found for kal_ckpt_multi_train: 111000
# kal_ckpt_multi_train: 112000
# File not found for kal_ckpt_multi_train: 113000
# File not found for kal_ckpt_multi_train: 114000
# File not found for kal_ckpt_multi_train: 115000
# File not found for kal_ckpt_multi_train: 116000
# File not found for kal_ckpt_multi_train: 117000
# File not found for kal_ckpt_multi_train: 118000
# File not found for kal_ckpt_multi_train: 119000
# File not found for kal_ckpt_multi_train: 120000
# File not found for kal_ckpt_multi_train: 121000
# kal_ckpt_multi_train: 122000
# File not found for kal_ckpt_multi_train: 123000
# File not found for kal_ckpt_multi_train: 124000
# File not found for kal_ckpt_multi_train: 125000
# File not found for kal_ckpt_multi_train: 126000
# File not found for kal_ckpt_multi_train: 127000
# File not found for kal_ckpt_multi_train: 128000
# File not found for kal_ckpt_multi_train: 129000
# File not found for kal_ckpt_multi_train: 130000
# File not found for kal_ckpt_multi_train: 131000
# kal_ckpt_multi_train: 132000
# File not found for kal_ckpt_multi_train: 133000
# File not found for kal_ckpt_multi_train: 134000
# File not found for kal_ckpt_multi_train: 135000
# File not found for kal_ckpt_multi_train: 136000
# File not found for kal_ckpt_multi_train: 137000
# File not found for kal_ckpt_multi_train: 138000
# File not found for kal_ckpt_multi_train: 139000
# File not found for kal_ckpt_multi_train: 140000
# File not found for kal_ckpt_multi_train: 141000
# kal_ckpt_multi_train: 142000
# File not found for kal_ckpt_multi_train: 143000
# File not found for kal_ckpt_multi_train: 144000
# File not found for kal_ckpt_multi_train: 145000
# File not found for kal_ckpt_multi_train: 146000
# File not found for kal_ckpt_multi_train: 147000
# File not found for kal_ckpt_multi_train: 148000
# File not found for kal_ckpt_multi_train: 149000
# File not found for kal_ckpt_multi_train: 150000
# File not found for kal_ckpt_multi_train: 151000
# kal_ckpt_multi_train: 152000
# File not found for kal_ckpt_multi_train: 153000
# File not found for kal_ckpt_multi_train: 154000
# File not found for kal_ckpt_multi_train: 155000
# File not found for kal_ckpt_multi_train: 156000
# File not found for kal_ckpt_multi_train: 157000
# File not found for kal_ckpt_multi_train: 158000
# File not found for kal_ckpt_multi_train: 159000
# File not found for kal_ckpt_multi_train: 160000
# File not found for kal_ckpt_multi_train: 161000
# kal_ckpt_multi_train: 162000
# File not found for kal_ckpt_multi_train: 163000
# File not found for kal_ckpt_multi_train: 164000
# File not found for kal_ckpt_multi_train: 165000
# File not found for kal_ckpt_multi_train: 166000
# File not found for kal_ckpt_multi_train: 167000
# File not found for kal_ckpt_multi_train: 168000
# File not found for kal_ckpt_multi_train: 169000
# File not found for kal_ckpt_multi_train: 170000
# File not found for kal_ckpt_multi_train: 171000
# kal_ckpt_multi_train: 172000
# File not found for kal_ckpt_multi_train: 173000
# File not found for kal_ckpt_multi_train: 174000
# File not found for kal_ckpt_multi_train: 175000
# File not found for kal_ckpt_multi_train: 176000
# File not found for kal_ckpt_multi_train: 177000
# File not found for kal_ckpt_multi_train: 178000
# File not found for kal_ckpt_multi_train: 179000
# File not found for kal_ckpt_multi_train: 180000
# File not found for kal_ckpt_multi_train: 181000
# kal_ckpt_multi_train: 182000

# %%
print("batch_size: ", batch_size)
print("gpus: ", gpus)
print("batch_size*kal_ckpt_multi_train: ", batch_size*kal_ckpt_multi_train)
# Out:
# batch_size:  512
# gpus:  1
# batch_size*kal_ckpt_multi_train:  93184000

# %%
tf_err_rat_zero_train -= 1
for ir in range(3):
    ols_irs[ir] -= 1

for i in range(len(tf_err_multi_trains)):
    tf_err_multi_trains[i] -= 1

# %%
def scientific_notation(value):
    """
    Returns the exponent and value of the scientific notation of an integer.
    
    Parameters:
    value (int): The integer to convert to scientific notation.
    
    Returns:
    tuple: A tuple containing the value and exponent of the scientific notation.
    """
    if value == 0:
        return (0, 0)
    
    exponent = 0
    while abs(value) >= 10:
        value /= 10
        exponent += 1
    while abs(value) < 1:
        value *= 10
        exponent -= 1

    value = round(value, 2)
    
    return (value, exponent)

# %%
from matplotlib.colors import BoundaryNorm, ListedColormap

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
context_len = 251

# colors = ['#000000', '#005CAB', '#E31B23', '#FFC325', '#00A651', '#9B59B6', '#FF69B4', '#8B4513']

#make a colormap for len(tf_err_multi_trains) + 4 colors
# colors = plt.cm.viridis(np.linspace(0, 1, len(tf_err_multi_trains) + 5))
# print(np.linspace(0, 1, len(tf_err_multi_trains) + 5))
# intervals = np.linspace(0, 60, len(tf_err_multi_trains))
# intervals = (0.97)**(intervals)
# # intervals -= intervals.min()
# # intervals = 1 - intervals
# #reverse the intervals
# intervals = intervals[::-1]
# print(intervals)
# start = 0.01
# stop = 0.99
# eps = 0
# number_of_lines=len(tf_err_multi_trains)
# inter = start
# intervals = []
# for i in range(number_of_lines):
#     intervals.append(inter)
#     inter += eps
#     if i % 25 == 0:
#         eps += 0.015

# #add 1 to every element in intervals
# # intervals = np.array(intervals)
# # intervals -= 0.2
# # intervals = intervals/np.max(intervals)
# # print(intervals)

frac = 0.4
intervals = np.linspace(0,1, int(frac*len(tf_err_multi_trains))+1)
intervals = np.array(intervals)
intervals += 0.4
print(intervals)
print(len(intervals))

cmap = plt.cm.Greys
# norm = BoundaryNorm(intervals, cmap.N)


colors_1 = cmap(intervals)

intervals = np.linspace(0,1, int((1-frac)*len(tf_err_multi_trains))+1)
print(intervals)

cmap2 = plt.cm.magma
# norm2 = BoundaryNorm(intervals, cmap2.N)
colors_2 = cmap2(intervals)


combined_colors = np.vstack((colors_1, colors_2))

#add a single dark neon blue color to the middle of the combined colors
add_color = np.array([0.0, 0.5, 1.0, 1.0])


# After you have filled examples_list:
target_examples = 6.25e7

# multiply all elements of ckpt_steps by batch_size*gpus to get examples_list_orig
examples_list_orig = np.array(ckpt_steps) * batch_size * gpus

# Find the index where examples_list is closest to target_examples
insert_idx = np.argmin(np.abs(np.array(examples_list_orig) - target_examples))


# Insert the dark blue color at the correct position
combined_colors = np.insert(combined_colors, insert_idx, add_color, axis=0)

combined_cmap = ListedColormap(combined_colors)

combined_intervals = np.linspace(0, 1, len(combined_colors))


# zero_steps = scientific_notation(2048*kal_ckpt_zero_train)
# steps_180k = scientific_notation(180000*batch_size*gpus)
# steps_96k = scientific_notation(96000*batch_size*gpus)
# steps_30k = scientific_notation(30000*batch_size*gpus)
# steps_3k = scientific_notation(3000*batch_size*gpus)

# ax.plot(np.arange(context_len), tf_err_rat_zero_train[1], label=f"Zero-cut Trained at {zero_steps[0]}e{zero_steps[1]} examples", linewidth=2, marker="x", markersize=2, zorder=5, color = colors[1])#linestyle="--")
# ax.fill_between(np.arange(context_len), tf_err_rat_zero_train[0], tf_err_rat_zero_train[2], alpha=0.2, color = colors[1])

# ax.plot(np.arange(context_len), tf_err_rat_multi_train_180k[1], label=f"Multi-cut Trained at {steps_180k[0]}e{steps_180k[1]} examples", linewidth=2, marker="x", markersize=2, zorder=4, color=colors[0])#, linestyle="-.")
# ax.fill_between(np.arange(context_len), tf_err_rat_multi_train_180k[0], tf_err_rat_multi_train_180k[2], alpha=0.2, color=colors[0])

# ax.plot(np.arange(context_len), tf_err_rat_multi_train_96k[1], label=f"Multi-cut Trained at {steps_96k[0]}e{steps_96k[1]} examples", linewidth=2, marker="x", markersize=2, zorder=3, color=colors[5])#, linestyle="-.")
# ax.fill_between(np.arange(context_len), tf_err_rat_multi_train_96k[0], tf_err_rat_multi_train_96k[2], alpha=0.2, color=colors[5])

# ax.plot(np.arange(context_len), tf_err_rat_multi_train_30k[1], label=f"Multi-cut Trained at {steps_30k[0]}e{steps_30k[1]} examples", linewidth=2, marker="x", markersize=2, zorder=2, color=colors[7])#, linestyle="-.")
# ax.fill_between(np.arange(context_len), tf_err_rat_multi_train_30k[0], tf_err_rat_multi_train_30k[2], alpha=0.2, color=colors[7])


# ax.plot(np.arange(context_len), tf_err_rat_multi_train_3k[1], label=f"Multi-cut Trained at {steps_3k[0]}e{steps_3k[1]} examples", linewidth=2, marker="x", markersize=2, zorder=2, color=colors[6])#, linestyle="-.")
# ax.fill_between(np.arange(context_len), tf_err_rat_multi_train_3k[0], tf_err_rat_multi_train_3k[2], alpha=0.2, color=colors[6])

# ax.plot(np.arange(context_len), an_sim_err_multi_train[1], label="Analytical Simulation", linewidth=2, marker=".", markersize=10)
# ax.fill_between(np.arange(context_len), an_sim_err_multi_train[0], an_sim_err_multi_train[2], alpha=0.15)

# for ir in range(1, 4):
#     ax.plot(np.arange(context_len), ols_irs[ir-1][1], label=f"OLS-{ir}", linewidth=2, marker=".", markersize=2, color=colors[ir+1])
#     ax.fill_between(np.arange(context_len), ols_irs[ir-1][0], ols_irs[ir-1][2], alpha=0.2, color=colors[ir+1])

# steps = np.arange(3000, 183000, 3000)
# examples_list = []
# colors = colors_1
# color_count = 0
# for i in range(len(tf_err_multi_trains)):
#     print(f"i: {i}, color_count: {color_count}")
#     if i > frac*len(tf_err_multi_trains):
#         colors = colors_2
#         if color_count == i:
#             color_count = 0
#     examples = steps[i]*batch_size*gpus
#     examples_list.append(examples)
#     examples = scientific_notation(examples)
#     ax.plot(np.arange(context_len), tf_err_multi_trains[i][1], label=f"Multi-cut Trained at {examples[0]}e{examples[1]} examples", linewidth=2, marker="x", markersize=2, color=colors[color_count])
#     color_count += 1


# steps = np.arange(1000, max_ckpt, 1000)
examples_list = []
color_count = 0
for i in range(len(tf_err_multi_trains)):
    print(f"i: {i}, color_count: {color_count}")
    examples = ckpt_steps[i]*batch_size*gpus
    examples_list.append(examples)
    examples = scientific_notation(examples)
    ax.plot(np.arange(context_len), tf_err_multi_trains[i][1], label=f"Multi-cut Trained at {examples[0]}e{examples[1]} examples", linewidth=2, marker="x", markersize=2, color=combined_colors[color_count])
    if i == insert_idx:

        fig.text(0.66,0.17, f"{examples[0]}e{examples[1]} ex", fontweight=10)
    color_count += 1

    # ax.fill_between(np.arange(context_len), tf_err_multi_trains[i][0], tf_err_multi_trains[i][2], alpha=0.2, color=colors[i+5])

ax.set_xlabel("Context", fontsize=16)
ax.set_xlim([2, context_len])
ax.set_ylabel("Error", fontsize=16)
# ax.legend()
ax.set_yscale("log")
ax.set_xscale("log")
ax.grid(True)
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.grid(which='major', linestyle='-', linewidth='0.5', color='black')
# ax.set_ylim([5e-2, 3e0])

# Adding a colorbar

# After filling examples_list:
examples_array = np.array(examples_list)
# Compute boundaries: midpoints between each example count
boundaries = np.zeros(len(examples_array) + 1)
boundaries[1:-1] = (examples_array[:-1] + examples_array[1:]) / 2
# Extend the first and last boundary
boundaries[0] = examples_array[0] - (examples_array[1] - examples_array[0]) / 2
boundaries[-1] = examples_array[-1] + (examples_array[-1] - examples_array[-2]) / 2

# Select every other tick for the colorbar
tick_indices = np.arange(0, len(examples_array), 2)
cbar_ticks = examples_array[tick_indices]

norm = BoundaryNorm(boundaries, combined_cmap.N)
sm = plt.cm.ScalarMappable(cmap=combined_cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, boundaries=boundaries, ticks=cbar_ticks)
cbar.set_label("# of Training Examples", fontsize=14, rotation=270, labelpad=20)
cbar.ax.set_yticklabels([f"{int(x):.0e}" for x in cbar_ticks])  # scientific notation

plt.tight_layout()

plt.show()

timestamp = time.strftime("%y%m%d_%H")

os.makedirs("../outputs/GPT2/" + experiment_multi_train + "/figures/context", exist_ok=True)
fig.savefig("../outputs/GPT2/" + experiment_multi_train + f"/figures/context/context_plot_{timestamp}.pdf", format="pdf")
# Out:
# [0.4        0.47142857 0.54285714 0.61428571 0.68571429 0.75714286
#  0.82857143 0.9        0.97142857 1.04285714 1.11428571 1.18571429
#  1.25714286 1.32857143 1.4       ]
# 15
# [0.         0.04761905 0.0952381  0.14285714 0.19047619 0.23809524
#  0.28571429 0.33333333 0.38095238 0.42857143 0.47619048 0.52380952
#  0.57142857 0.61904762 0.66666667 0.71428571 0.76190476 0.80952381
#  0.85714286 0.9047619  0.95238095 1.        ]
# i: 0, color_count: 0
# i: 1, color_count: 1
# i: 2, color_count: 2
# i: 3, color_count: 3
# i: 4, color_count: 4
# i: 5, color_count: 5
# i: 6, color_count: 6
# i: 7, color_count: 7
# i: 8, color_count: 8
# i: 9, color_count: 9
# i: 10, color_count: 10
# i: 11, color_count: 11
# i: 12, color_count: 12
# i: 13, color_count: 13
# i: 14, color_count: 14
# i: 15, color_count: 15
# i: 16, color_count: 16
# i: 17, color_count: 17
# i: 18, color_count: 18
# i: 19, color_count: 19
# i: 20, color_count: 20
# i: 21, color_count: 21
# i: 22, color_count: 22
# i: 23, color_count: 23
# i: 24, color_count: 24
# i: 25, color_count: 25
# i: 26, color_count: 26
# i: 27, color_count: 27
# i: 28, color_count: 28
# i: 29, color_count: 29
# i: 30, color_count: 30
# i: 31, color_count: 31
# i: 32, color_count: 32
# i: 33, color_count: 33
# i: 34, color_count: 34
# i: 35, color_count: 35

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

cmap = plt.cm.magma

colors = cmap(np.linspace(0, 1, len(np.arange(context_len))))

for context in np.arange(0, context_len):
    train_convs = [tf_err_multi_trains[i][1][context] for i in range(len(tf_err_multi_trains))]

    ax.plot(examples_list, train_convs, label=f"context: {context}", linewidth=2, marker="x", markersize=4, color=colors[context])

#place a red dotted vertical line at early_stop*batch_size*gpus
early_stop = 122000
ax.axvline(x=early_stop*batch_size*gpus, color='red', linestyle='--', linewidth=2)
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel("# of Training Examples", fontsize=12)
ax.set_ylabel("Error", fontsize=12)
ax.set_xlim([1e3*batch_size*gpus, max_ckpt*batch_size*gpus])
ax.grid(True)
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.grid(which='major', linestyle='-', linewidth='0.5', color='black')

#add colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=5, vmax=context_len))
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label("Context", fontsize=12, rotation=270, labelpad=15)

plt.tight_layout()

fig_dir = "../outputs/GPT2/" + experiment_multi_train + "/figures/context"
os.makedirs(fig_dir, exist_ok=True)
timestamp = time.strftime("%y%m%d_%H%M")
fig.savefig(f"{fig_dir}/context_train_conv_plot_{timestamp}.pdf", format="pdf")

plt.show()

# %% [markdown]
# ## zero cut train conv

# %%
valA = "gaussA"
valC = "_gauss_C"
state_dim = 10
batch_size = 512 #512 #4096
gpus=2
num_val_sys = 25
experiment1 = "250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000" # experiment to load
experiment2 = "250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000"
datasource = "val"
nope = False
single_system = False
zero_cut = True


compute_more_ckpts = True

# %%
kal_ckpts = [180000, 90000]  #60000 #81000 #28500
train_conv_plots([experiment1, experiment2], ["Multi-cut Trained", "Zero-cut Trained"], kal_ckpts, valA, valC, num_val_sys, compute_more_ckpts, 200, 1000, 180000, 1000, state_dim, single_system=single_system, nope=nope, batch_size=batch_size, gpus=gpus, zero_cut=zero_cut)
# Out:
# /home/sultand/TFs_do_KF_ICL/outputs/train_conv/training_dist_comparison_val_gaussA_state_dim_10_val_sys_25_1738272480.9015734.pdf
# quantiles 5 path exists?: True
# ckpt_steps: [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000, 50000, 51000, 52000, 53000, 54000, 55000, 56000, 57000, 58000, 59000, 60000, 61000, 62000, 63000, 64000, 65000, 66000, 67000, 68000, 69000, 70000, 71000, 72000, 73000, 74000, 75000, 76000, 77000, 78000, 79000, 80000, 81000, 82000, 83000, 84000, 85000, 86000, 87000, 88000, 89000, 90000, 91000, 92000, 93000, 94000, 95000, 96000, 97000, 98000, 99000, 100000, 101000, 102000, 103000, 104000, 105000, 106000, 107000, 108000, 109000, 110000, 111000, 112000, 113000, 114000, 115000, 116000, 117000, 118000, 119000, 120000, 121000, 122000, 123000, 124000, 125000, 126000, 127000, 128000, 129000, 130000, 131000, 132000, 133000, 134000, 135000, 136000, 137000, 138000, 139000, 140000, 141000, 142000, 143000, 144000, 145000, 146000, 147000, 148000, 149000, 150000, 151000, 152000, 153000, 154000, 155000, 156000, 157000, 158000, 159000, 160000, 161000, 162000, 163000, 164000, 165000, 166000, 167000, 168000, 169000, 170000, 171000, 172000, 173000, 174000, 175000, 176000, 177000, 178000, 179000, 180000]
#
#
# i 0
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=180000.ckpt/zero_cut_gaussA_state_dim_10_err_lss.pkl
# loaded Kalman_rem error
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=1000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=2000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=3000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=4000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=5000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=6000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=7000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=8000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=9000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=10000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=11000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=12000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=13000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=14000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=15000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=16000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=17000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=18000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=19000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=20000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=21000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=22000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=23000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=24000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=25000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=26000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=27000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=28000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=29000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=30000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=31000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=32000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=33000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=34000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=35000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=36000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=37000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=38000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=39000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=40000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=41000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=42000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=43000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=44000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=45000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=46000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=47000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=48000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=49000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=50000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=51000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=52000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=53000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=54000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=55000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=56000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=57000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=58000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=59000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=60000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=61000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=62000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=63000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=64000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=65000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=66000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=67000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=68000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=69000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=70000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=71000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=72000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=73000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=74000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=75000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=76000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=77000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=78000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=79000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=80000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=81000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=82000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=83000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=84000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=85000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=86000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=87000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=88000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=89000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=90000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=91000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=92000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=93000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=94000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=95000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=96000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=97000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=98000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=99000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=100000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=101000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=102000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=103000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=104000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=105000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=106000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=107000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=108000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=109000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=110000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=111000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=112000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=113000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=114000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=115000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=116000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=117000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=118000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=119000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=120000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=121000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=122000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=123000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=124000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=125000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=126000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=127000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=128000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=129000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=130000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=131000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=132000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=133000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=134000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=135000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=136000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=137000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=138000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=139000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=140000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=141000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=142000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=143000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=144000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=145000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=146000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=147000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=148000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=149000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=150000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=151000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=152000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=153000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=154000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=155000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# /home/sultand/TFs_do_KF_ICL/outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=156000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# Loaded Transformer Errors
# ratios shape: torch.Size([25, 2000, 251])
# ratios shape after median: torch.Size([25, 251])
# quantile shape: torch.Size([3])
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=157000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250114_202420.3c1184_multi_sys_trace_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=158000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# ...
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=141000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=142000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=143000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=144000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=145000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=146000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=147000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=148000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=149000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=150000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=151000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=152000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=153000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=154000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=155000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=156000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=157000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=158000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=159000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=160000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=161000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=162000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=163000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=164000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=165000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=166000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=167000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=168000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=169000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=170000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=171000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=172000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=173000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=174000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=175000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=176000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=177000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=178000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=179000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# path does not exist: ../outputs/GPT2/250127_001511.3ac954_multi_sys_trace_zero_cut_gaussA_state_dim_10_gauss_C_lr_1.584893192461114e-05_num_train_sys_40000/prediction_errors_gauss_C_step=180000.ckpt/train_conv_zero_cut_gaussA_state_dim_10_err_lss.pkl
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# quantiles shape (91, 3)
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# (array([0.2527598 , 0.41225517, 0.5662619 ], dtype=float32),
#  [3072000,
#   6144000,
#   9216000,
#   12288000,
#   15360000,
#   18432000,
#   21504000,
#   24576000,
#   27648000,
#   30720000,
#   33792000,
#   36864000,
#   39936000,
#   43008000,
#   46080000,
#   49152000,
#   52224000,
#   55296000,
#   58368000,
#   61440000,
#   64512000,
#   67584000,
#   70656000,
#   73728000,
#   76800000,
#   79872000,
#   82944000,
#   86016000,
#   89088000,
#   92160000,
#   95232000,
#   98304000,
#   101376000,
#   104448000,
#   107520000,
#   110592000,
#   113664000,
#   116736000,
#   119808000,
#   122880000,
#   125952000,
#   129024000,
#   132096000,
#   135168000,
#   138240000,
#   141312000,
#   144384000,
#   147456000,
#   150528000,
#   153600000,
#   156672000,
#   159744000,
#   162816000,
#   165888000,
#   168960000,
#   172032000,
#   175104000,
#   178176000,
#   181248000,
#   184320000])
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
